# %%
import math
import random
import numpy as np
from math import gcd
import RSA_Module

# %%
BIT_LENGTH = 8
#Generate private and public key
public_key, private_key = RSA_Module.generate_keypair(BIT_LENGTH)

print("Public key: ", public_key)
print("Private key: ", private_key)
# Out:
# 17 11
# Public key:  (43, 187)
# Private key:  (67, 187)

# %%
MESSAGE = "Hello Quantum"

ciphertext, encrypted_object = RSA_Module.encrypt(
    MESSAGE,
    public_key
)
print(ciphertext)
# Out:
# 18311812412410043174145911219514565

# %%
decrypted_msg = RSA_Module.decrypt(encrypted_object, private_key)

print("\nDecrypted message using RSA Algorithm: " + decrypted_msg)
# Out:
# Decrypted message using RSA Algorithm: Hello Quantum
